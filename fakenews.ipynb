# %%
import pandas as pd
df = pd.read_csv("C:\Users\zebronics\Downloads\unsupervised learning\fakenews.csv")
print(df.head())
# Out:
#   Cell In[4], line 2
#     df = pd.read_csv("C:\Users\zebronics\Downloads\unsupervised learning\fakenews.csv")
#                                                                                       ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape
